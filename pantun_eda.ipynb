# %% [markdown]
# # Memahami Data Pantun Yang Baru kita Kikis (Scraping) dari laman sesawang
# Berpandukan laman sesawang sejuta pantun, saya telah pun mengikis sehingga 400 m/s pantun dengan jumlah melebih 5000 koleksi pantun. Koleksi pantun ini perlu disusun dalama bentuk dataset yang membolehkan kita melakukan fine-tuning.

# %%
import csv

# Define the input and output file paths
input_file = 'pantun_dataset2.txt'
output_file = 'structured_pantun.csv'

# Open the input file and parse its content
with open(input_file, 'r', encoding='utf-8') as f:
    pantuns = f.read().strip().split('\n\n')  # Split by double newline to get each pantun stanza

# Create the CSV file to save the structured data
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Pantun_ID', 'Line_1', 'Line_2', 'Line_3', 'Line_4']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate over each pantun and write to CSV
    for i, pantun in enumerate(pantuns):
        lines = pantun.split('\n')
        if len(lines) == 4:  # Ensure it's a complete pantun with 4 lines
            writer.writerow({
                'Pantun_ID': f'Pantun_{i + 1}',
                'Line_1': lines[0],
                'Line_2': lines[1],
                'Line_3': lines[2],
                'Line_4': lines[3]
            })

print("Pantun structuring completed. Data saved to structured_pantun.csv.")
# Out:
# Pantun structuring completed. Data saved to structured_pantun.csv.

# %%
import pandas as pd
import numpy as np

df= pd.read_csv('structured_pantun.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2428 entries, 0 to 2427
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pantun_ID  2428 non-null   object
#  1   Line_1     2428 non-null   object
#  2   Line_2     2428 non-null   object
#  3   Line_3     2428 non-null   object
#  4   Line_4     2428 non-null   object
# dtypes: object(5)
# memory usage: 95.0+ KB

# %%
df.tail(5)
# Out:
#          Pantun_ID                        Line_1  \
# 2423  Pantun_16893  Hujan dimuara air nya deras,
# 2424  Pantun_16894  Hujan di muara airnya deras,
# 2425  Pantun_16895   Hujan dimuara airnya deras.
# 2426  Pantun_16896  Hujung dimuara airnya deras,
# 2427  Pantun_16897    Terang bulan bagai diukir,
#
#                              Line_2                                    Line_3  \
# 2423     Payong sekaki kongsi sama;            Radio klasik sentiasa di hias,
# 2424     Payong sekaki kongsi sama;       Banjar datang harta benda terjejas,
# 2425  Payung sekaki berkongsi sama;  Musim ketengkujuh perlu peka dan cerdas,
# 2426  Payung sekali berkongsi sama;         Bergotong royong janganlah malas,
# 2427   Tupai mengusik bunga durian;        Sebarang perbuatan habiskan fikir,
#
#                                            Line_4
# 2423                   Dengan lagu baru dan lama.
# 2424            Demi keselamatan jagalah bersama.
# 2425  Keselamatan keluarga tanggungjawab bersama.
# 2426                   Saat banjir nyawa diutama.
# 2427                Tidak menyesal hari kemudian.

# %%
import csv
import json

# Define the input and output file paths
input_file = 'pantun_dataset2.txt'
output_csv_file = 'structured_pantun.csv'
output_jsonl_file = 'pantun_finetune_dataset.jsonl'

# Open the input file and parse its content
with open(input_file, 'r', encoding='utf-8') as f:
    pantuns = f.read().strip().split('\n\n')  # Split by double newline to get each pantun stanza

# Create the CSV file to save the structured data
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Pantun_ID', 'Line_1', 'Line_2', 'Line_3', 'Line_4']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate over each pantun and write to CSV
    for i, pantun in enumerate(pantuns):
        lines = pantun.split('\n')
        if len(lines) == 4:  # Ensure it's a complete pantun with 4 lines
            writer.writerow({
                'Pantun_ID': f'Pantun_{i + 1}',
                'Line_1': lines[0],
                'Line_2': lines[1],
                'Line_3': lines[2],
                'Line_4': lines[3]
            })

print("Pantun structuring completed. Data saved to structured_pantun.csv.")

# Create the JSONL file for fine-tuning
with open(output_jsonl_file, 'w', encoding='utf-8') as jsonlfile:
    with open(output_csv_file, 'r', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            # Create a prompt-completion pair
            prompt = f"{row['Line_1']}\n{row['Line_2']}"
            completion = f"\n{row['Line_3']}\n{row['Line_4']}"
            
            # Write the pair in JSONL format
            json.dump({"prompt": prompt, "completion": completion}, jsonlfile)
            jsonlfile.write('\n')

print("Pantun fine-tuning dataset saved to pantun_finetune_dataset.jsonl.")
# Out:
# Pantun structuring completed. Data saved to structured_pantun.csv.
# Pantun fine-tuning dataset saved to pantun_finetune_dataset.jsonl.

# %%
# Code to view the JSONL file in Jupyter Notebook
import pandas as pd

# Load the JSONL file into a DataFrame for easy viewing
jsonl_file = 'pantun_finetune_dataset.jsonl'

with open(jsonl_file, 'r', encoding='utf-8') as f:
    lines = [json.loads(line) for line in f]

# Create a DataFrame from the JSONL lines
df2 = pd.DataFrame(lines)

# Display the first few rows of the DataFrame
df2.head()
# Out:
#                                               prompt  \
# 0  Burung dara, burung nuri,\nBernyanyi bersama d...
# 1  Tangan memberi dengan ikhlas,\nTangan menerima...
# 2  Tersandung kaki tersilap langkah,\nLutut berda...
# 3  Pokok turi tinggi segalah,\nDi hujung taman te...
# 4  Majlis meriah ramai kenalan,\nAntara disaji pu...
#
#                                           completion
# 0  \nTak kira berapa yg diberi,\nBiar keikhlasan ...
# 1  \nSenyum ku beri dia membalas,\nJalan kedepan ...
# 2  \nSucikan hati dengan bersedekah,\nAgar hidup ...
# 3  \nIkhlas memberi kerana ALLAH,\nSubur iman ber...
# 4  \nSedekah jariah bukan tontonan,\nBiarlah menj...

# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (0.8.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2024.8.30)

# %%
import json
import pandas as pd
from dotenv import load_dotenv
import os
import tiktoken

# Load environment variables from .env file
load_dotenv()

# Load the JSONL file into a DataFrame for easy viewing
jsonl_file = 'pantun_finetune_dataset.jsonl'

with open(jsonl_file, 'r', encoding='utf-8') as f:
    lines = [json.loads(line) for line in f]

# Create a DataFrame from the JSONL lines
df = pd.DataFrame(lines)

# Display the first few rows of the DataFrame
df.head()

# Calculate the number of tokens for each prompt and completion
def num_tokens_from_string(string: str, encoding_name: str = "gpt-3.5-turbo") -> int:
    encoding = tiktoken.encoding_for_model(encoding_name)
    return len(encoding.encode(string))

# Add columns for the number of tokens in each prompt and completion
df['prompt_tokens'] = df['prompt'].apply(lambda x: num_tokens_from_string(x))
df['completion_tokens'] = df['completion'].apply(lambda x: num_tokens_from_string(x))
df['total_tokens'] = df['prompt_tokens'] + df['completion_tokens']

# Display the total number of tokens in the dataset
total_tokens = df['total_tokens'].sum()
print("Total number of tokens in the dataset:", total_tokens)
# Out:
# Total number of tokens in the dataset: 103394

# %%
# !pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from openai==0.28) (4.65.0)
# Requirement already satisfied: aiohttp in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from openai==0.28) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from requests>=2.20->openai==0.28) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from requests>=2.20->openai==0.28) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from requests>=2.20->openai==0.28) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from requests>=2.20->openai==0.28) (2024.8.30)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from aiohttp->openai==0.28) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from aiohttp->openai==0.28) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/abuhuzaifahbidin/miniconda3/lib/python3.12/site-packages (from aiohttp->openai==0.28) (1.9.4)

# %%
#mari buat pantun
import openai
from dotenv import load_dotenv
import os
import tiktoken
import time

# Load environment variables from a .env file (optional, if you use one)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# Function to use the fine-tuned model
# Function to use the fine-tuned model, ensuring only 4-line stanza pantun is returned
def generate_pantun(prompt, model="ft:davinci-002:personal:pantun-eksperimen3:AHhDFKx3", temperature=0.7, max_tokens=150):
    response = openai.Completion.create(
        model=model,
        prompt=prompt,
        temperature=temperature,
        max_tokens=max_tokens,
        stop="\n\n"
    )
    pantun = response.choices[0].text.strip()
    # Ensure the generated response contains exactly 4 lines (4 stanza pantun)
    lines = pantun.split("\n")
    return ''.join(lines[:4]) 

# Example usage of the fine-tuned model
prompt = "Pergi mengail di tepi tasik"
response = generate_pantun(prompt)
print("Generated pantun:", response)
# Out:
# Generated pantun:

# %%
import csv
import re

# Define the input and output file paths
input_file = 'pantun_dataset3.txt'
output_file = 'structured_pantun2.csv'

# Open the input file and parse its content
with open(input_file, 'r', encoding='utf-8') as f:
    pantuns = f.read().strip().split('\n\n')  # Split by double newline to get each pantun stanza

# Create the CSV file to save the structured data
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Pantun_ID', 'Line_1', 'Line_2', 'Line_3', 'Line_4']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate over each pantun and write to CSV
    for i, pantun in enumerate(pantuns):
        # Split the pantun by punctuation marks followed by whitespace or newlines
        lines = re.split(r'[.,;!?]\s+|\n', pantun)
        lines = [line.strip() for line in lines if line.strip() != '']  # Remove empty lines
        
        # Group lines into sets of 4
        for j in range(0, len(lines), 4):
            if j + 4 <= len(lines):
                writer.writerow({
                    'Pantun_ID': f'Pantun_{i + 1}_{(j // 4) + 1}',
                    'Line_1': lines[j],
                    'Line_2': lines[j + 1],
                    'Line_3': lines[j + 2],
                    'Line_4': lines[j + 3]
                })

print("Pantun structuring completed. Data saved to structured_pantun2.csv.")
# Out:
# Pantun structuring completed. Data saved to structured_pantun2.csv.

# %%
import pandas as pd
import numpy as np

df3= pd.read_csv('structured_pantun2.csv')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pantun_ID  2998 non-null   object
#  1   Line_1     2998 non-null   object
#  2   Line_2     2998 non-null   object
#  3   Line_3     2998 non-null   object
#  4   Line_4     2998 non-null   object
# dtypes: object(5)
# memory usage: 117.2+ KB

# %%
df3
# Out:
#            Pantun_ID                                             Line_1  \
# 0      Pantun_2541_1                                             Lemang
# 1      Pantun_7181_1                    Norma baru antaranya berwebinar
# 2      Pantun_7182_1                          Rayuan datang demi rayuan
# 3      Pantun_7183_1                          Masak gulai ikan tenggiri
# 4      Pantun_7185_1                  Kalau berkunjung ke negeri Perlis
# ...              ...                                                ...
# 2993  Pantun_19013_1                Ada 3 orang dalam sebuah kapal laut
# 2994  Pantun_19015_1                                     Biar mati anak
# 2995  Pantun_19017_1                       "Jika dunia ini persinggahan
# 2996  Pantun_19175_1  Beginilah semuanyaSakit bermula mati bersebabH...
# 2997  Pantun_19323_1                       Melabuh pukat di tengah laut
#
#                                                  Line_2  \
# 0                                               lontong
# 1                      Penyertaan meluas ke luar negeri
# 2                              Jangan mudah undi diberi
# 3                         Dicampur dengan santan kelapa
# 4                          Rasailah kari ikan nyuk-nyuk
# ...                                                 ...
# 2993                                       seorang nabi
# 2994               jangan mati adat,Tak lapuk dek hujan
# 2995  mengapa tidak kita perbanyakkan bekalan untuk ...
# 2996                                               maut
# 2997                   Perahu terdampar di Pulau Berudu
#
#                                                  Line_3  \
# 0                                               rendang
# 1                  Walaupun rentas negeri telah dibenar
# 2                    Rumahtangga dibina dengan kesucian
# 3                           Usahlah digadai maruah diri
# 4                                      eruskan berfikir
# ...                                                 ...
# 2993            seorang maharaja dan seorang hamba abdi
# 2994            tak lekang dek panas.Bersatu kita teguh
# 2995  kerana kita cuma ada satu persinggahan" "Dalam...
# 2996                                     tanah berbaris
# 2997                           Lara hati jangan diturut
#
#                                                  Line_4
# 0                                              ketupat,
# 1                     Berhati-hatilah dan jagalah diri.
# 2                  Keberkatan hidup itulah yang dicari.
# 3                     Laba duniawi yang tidak seberapa.
# 4                                       membaca menulis
# ...                                                 ...
# 2993                       Kapal laut itu pun tenggelam
# 2994      bercerai kita roboh.Tak kenal maka tak cinta.
# 2995           Dalam kemiskinan ada harta kekayaan jiwa
# 2996  jodoh pertemuanSemuanya di tangan TuhanJadi se...
# 2997                      Jangan diikut hati yang beku.
#
# [2998 rows x 5 columns]

# %%
import csv
import json

# Define the input and output file paths
input_file = 'pantun_dataset2.txt'
output_csv_file = 'structured_pantun.csv'
output_jsonl_file = 'pantun_finetune_dataset3.jsonl'

# Open the input file and parse its content
with open(input_file, 'r', encoding='utf-8') as f:
    pantuns = f.read().strip().split('\n\n')  # Split by double newline to get each pantun stanza

# Create the CSV file to save the structured data
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Pantun_ID', 'Line_1', 'Line_2', 'Line_3', 'Line_4']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate over each pantun and write to CSV
    for i, pantun in enumerate(pantuns):
        lines = pantun.split('\n')
        if len(lines) == 4:  # Ensure it's a complete pantun with 4 lines
            writer.writerow({
                'Pantun_ID': f'Pantun_{i + 1}',
                'Line_1': lines[0],
                'Line_2': lines[1],
                'Line_3': lines[2],
                'Line_4': lines[3]
            })

print("Pantun structuring completed. Data saved to structured_pantun.csv.")

# Create the JSONL file for fine-tuning
with open(output_jsonl_file, 'w', encoding='utf-8') as jsonlfile:
    with open(output_csv_file, 'r', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            # Create the JSONL structure for GPT-4o-mini fine-tuning
            jsonl_data = {
                "messages": [
                    {"role": "system", "content": "A pantun typically consists of four lines where the end of the first line rhymes with the end of the third line, and the end of the second line rhymes with the end of the fourth line. The lines should have a rhythmic flow and convey a meaningful message."},
                    {"role": "user", "content": row['Line_1']},
                    {"role": "assistant", "content": f"{row['Line_2']}; {row['Line_3']}; {row['Line_4']}"}
                ]
            }
            # Write the data in JSONL format
            json.dump(jsonl_data, jsonlfile)
            jsonlfile.write('\n')

print("Pantun fine-tuning dataset saved to pantun_finetune_dataset3.jsonl.")
# Out:
# Pantun structuring completed. Data saved to structured_pantun.csv.
# Pantun fine-tuning dataset saved to pantun_finetune_dataset3.jsonl.

# %%
#mari buat pantun
import openai
from dotenv import load_dotenv
import os
import tiktoken
import time

# Load environment variables from a .env file (optional, if you use one)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# Function to use the fine-tuned model, ensuring only 4-line stanza pantun is returned
def generate_pantun(prompt, model="ft:gpt-4o-2024-08-06:personal:pantun-eksperimen3:AI95NfUz", temperature=0.7, max_tokens=150):
    response = openai.ChatCompletion.create(
        model=model,
        messages=[
            {"role": "system", "content": "Pantunbot is a pantun generator able to continue a pantun given a pantun line. A pantun typically consists of four lines where the end of the first line rhymes with the end of the third line, and the end of the second line rhymes with the end of the fourth line. The lines should have a rhythmic flow and convey a meaningful message."},
            {"role": "user", "content": prompt}
        ],
        temperature=temperature,
        max_tokens=max_tokens
    )
    pantun = response['choices'][0]['message']['content'].strip()
    # Ensure the generated response contains exactly 4 lines (4 stanza pantun)
    lines = pantun.split("\n")
    return '\n'.join(lines[:4])

# Example usage of the fine-tuned model
prompt = "kurang pahala banyakkan dosa"
response = generate_pantun(prompt)
print("Generated pantun:", response)
# Out:
# Generated pantun: di bulan mulia banyakkan ibadah;; curiga jangan tanpa bicara,; aduannya palsu tiada sudah.
